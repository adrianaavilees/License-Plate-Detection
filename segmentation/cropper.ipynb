# %%
import cv2
import os
from ultralytics import YOLO
import shutil


class PlatePredictor:
    def __init__(self, model_path: str):
        """Carga el modelo entrenado (best.pt)"""
        self.model = YOLO(model_path)

    def predict_and_crop_folder(self, folder_path: str, conf: float = 0.25, save_dir: str = "crops"):
        """Predice todas las imágenes de una carpeta y guarda recortes"""
        results = self.model.predict(
            source=folder_path,
            save=True,
            conf=conf
        )

        # Crear carpeta de salida
        os.makedirs(save_dir, exist_ok=True)

        # Procesar resultados
        for r in results:
            image_path = r.path  # ruta de la imagen original
            img = cv2.imread(image_path)
            base_name = os.path.basename(image_path)

            for i, box in enumerate(r.boxes):
                # Coordenadas (x1, y1, x2, y2)
                x1, y1, x2, y2 = map(int, box.xyxy[0])

                # Recorte
                crop = img[y1:y2, x1:x2]

                # Nombre único para cada recorte
                crop_path = os.path.join(save_dir, f"crop_{i}_{base_name}")
                cv2.imwrite(crop_path, crop)

                print(f"Recorte guardado en {crop_path}")

        return results
    
    def predict_and_crop_image(self, image_path: str, conf: float = 0.25, save_dir: str = "crops"):
        """Predecir una sola imagen y guarda recortes"""

        # Borrar carpeta si existe y recrearla limpia
        if os.path.exists(save_dir):
            shutil.rmtree(save_dir)
        os.makedirs(save_dir)

        # Hacer predicción
        results = self.model.predict(
            source=image_path,
            save=True,
            conf=conf
        )

        # Leer imagen original
        img = cv2.imread(image_path)
        base_name = os.path.basename(image_path)

        for i, box in enumerate(results[0].boxes):
            # Coordenadas del bounding box
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            # Recorte
            crop = img[y1:y2, x1:x2]

            # Guardar recorte
            crop_path = os.path.join(save_dir, f"crop_{i}_{base_name}")
            cv2.imwrite(crop_path, crop)

            print(f" Recorte guardado en {crop_path}")

        return results

# %%
# Crear predictor 
model_path = "/Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Projecte1/License-Plate-Detection/best.pt"
predictor = PlatePredictor(model_path)

# Predecir y recortar todas las imágenes de la carpeta 
folder_path = "/Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Projecte1/License-Plate-Detection/Lateral"
results = predictor.predict_and_crop_folder(folder_path, conf=0.25, save_dir="Crops")
# Out:
# image 1/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_094926329.jpg: 256x448 1 License-Plate, 145.8ms
# image 2/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_094938026.jpg: 256x448 1 License-Plate, 135.0ms
# image 3/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_094946132.jpg: 256x448 1 License-Plate, 133.1ms
# image 4/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_094951899.jpg: 256x448 2 License-Plates, 132.6ms
# image 5/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_094959264.jpg: 256x448 1 License-Plate, 134.1ms
# image 6/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095022850.jpg: 256x448 1 License-Plate, 133.8ms
# image 7/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095032661.jpg: 256x448 2 License-Plates, 135.0ms
# image 8/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095042811.jpg: 256x448 1 License-Plate, 137.1ms
# image 9/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095052884.jpg: 256x448 1 License-Plate, 136.7ms
# image 10/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095103559.jpg: 256x448 1 License-Plate, 134.8ms
# image 11/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095112482.jpg: 256x448 1 License-Plate, 132.8ms
# image 12/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095129495.jpg: 256x448 1 License-Plate, 130.3ms
# image 13/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095142454.jpg: 256x448 1 License-Plate, 135.6ms
# image 14/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210921_095212294.jpg: 256x448 1 License-Plate, 133.7ms
# image 15/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210923_071335579.jpg: 256x448 1 License-Plate, 135.8ms
# image 16/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210923_071344764.jpg: 256x448 1 License-Plate, 135.2ms
# image 17/17 /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/Lateral/PXL_20210923_071356001.jpg: 256x448 1 License-Plate, 133.2ms
# Speed: 1.8ms preprocess, 135.0ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 448)
# Results saved to /Users/lianbaguebatlle/Desktop/Dades/Tercer/1rsemestre/PSIV2/Repte1/runs/detect/predict10
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_094926329.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_094938026.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_094946132.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_094951899.jpg
# ✅ Recorte guardado en Crops/crop_1_PXL_20210921_094951899.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_094959264.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095022850.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095032661.jpg
# ✅ Recorte guardado en Crops/crop_1_PXL_20210921_095032661.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095042811.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095052884.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095103559.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095112482.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095129495.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095142454.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210921_095212294.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210923_071335579.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210923_071344764.jpg
# ✅ Recorte guardado en Crops/crop_0_PXL_20210923_071356001.jpg
