# %%
import cv2
import os
from ultralytics import YOLO
import shutil


class PlatePredictor:
    def __init__(self, model_path: str):
        """Carga el modelo entrenado (best.pt)"""
        self.model = YOLO(model_path)

    def predict_and_crop_folder(self, folder_path: str, conf: float = 0.25, save_dir: str = "crops"):
        """Predice todas las imágenes de una carpeta y guarda recortes"""
        results = self.model.predict(
            source=folder_path,
            save=True,
            conf=conf
        )

        # Crear carpeta de salida
        os.makedirs(save_dir, exist_ok=True)

        # Procesar resultados
        for r in results:
            image_path = r.path  # ruta de la imagen original
            img = cv2.imread(image_path)
            base_name = os.path.basename(image_path)

            for i, box in enumerate(r.boxes):
                # Coordenadas (x1, y1, x2, y2)
                x1, y1, x2, y2 = map(int, box.xyxy[0])

                # Recorte
                crop = img[y1:y2, x1:x2]

                # Nombre único para cada recorte
                crop_path = os.path.join(save_dir, f"crop_{i}_{base_name}")
                cv2.imwrite(crop_path, crop)

                print(f"Recorte guardado en {crop_path}")

        return results
    
    def predict_and_crop_image(self, image_path: str, conf: float = 0.25, save_dir: str = "crops"):
        """Predecir una sola imagen y guarda recortes"""

        # Borrar carpeta si existe y recrearla limpia
        if os.path.exists(save_dir):
            shutil.rmtree(save_dir)
        os.makedirs(save_dir)

        # Hacer predicción
        results = self.model.predict(
            source=image_path,
            save=True,
            conf=conf
        )

        # Leer imagen original
        img = cv2.imread(image_path)
        base_name = os.path.basename(image_path)

        for i, box in enumerate(results[0].boxes):
            # Coordenadas del bounding box
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            # Recorte
            crop = img[y1:y2, x1:x2]

            # Guardar recorte
            crop_path = os.path.join(save_dir, f"crop_{i}_{base_name}")
            cv2.imwrite(crop_path, crop)

            print(f" Recorte guardado en {crop_path}")

        return results

# %%
# Crear predictor 
model_path = r"C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\License-Plate-Detection\models\best.pt"
predictor = PlatePredictor(model_path)

# Predecir y recortar todas las imágenes de la carpeta 
folder_path = r"C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test"
results = predictor.predict_and_crop_folder(folder_path, conf=0.25, save_dir="Crops")
# Out:
# image 1/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0535.jpg: 352x448 1 License-Plate, 691.1ms
# image 2/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0536.jpg: 352x448 1 License-Plate, 608.1ms
# image 3/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0538.jpg: 352x448 1 License-Plate, 370.1ms
# image 4/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0539.jpg: 352x448 2 License-Plates, 1122.9ms
# image 5/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0540.jpg: 352x448 1 License-Plate, 246.5ms
# image 6/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0541.jpg: 352x448 2 License-Plates, 604.7ms
# image 7/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0542.jpg: 352x448 1 License-Plate, 633.0ms
# image 8/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0543.jpg: 352x448 1 License-Plate, 887.9ms
# image 9/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0544.jpg: 352x448 1 License-Plate, 1000.0ms
# image 10/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0545.jpg: 352x448 1 License-Plate, 643.2ms
# image 11/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0546.jpg: 352x448 1 License-Plate, 1192.3ms
# image 12/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0547.jpg: 352x448 1 License-Plate, 799.7ms
# image 13/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0548.jpg: 352x448 1 License-Plate, 759.0ms
# image 14/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0549.jpg: 384x448 1 License-Plate, 1882.5ms
# image 15/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0550.jpg: 352x448 1 License-Plate, 313.0ms
# image 16/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0551.jpg: 352x448 1 License-Plate, 312.6ms
# image 17/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0552.jpg: 352x448 1 License-Plate, 1624.6ms
# image 18/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0553.jpg: 256x448 1 License-Plate, 305.5ms
# image 19/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0554.jpg: 352x448 1 License-Plate, 271.3ms
# image 20/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0555.jpg: 352x448 1 License-Plate, 904.5ms
# image 21/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0556.jpg: 352x448 1 License-Plate, 326.3ms
# image 22/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0557.jpg: 320x448 1 License-Plate, 736.0ms
# image 23/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0558.jpg: 352x448 1 License-Plate, 366.0ms
# image 24/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0559.jpg: 352x448 2 License-Plates, 295.2ms
# image 25/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0560.jpg: 352x448 1 License-Plate, 234.7ms
# image 26/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0561.jpg: 448x448 1 License-Plate, 940.7ms
# image 27/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0562.jpg: 352x448 2 License-Plates, 388.3ms
# image 28/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0563.jpg: 352x448 1 License-Plate, 616.3ms
# image 29/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0564.jpg: 352x448 2 License-Plates, 242.2ms
# image 30/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0565.jpg: 352x448 1 License-Plate, 289.8ms
# image 31/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0566.jpg: 352x448 1 License-Plate, 1235.2ms
# image 32/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0567.jpg: 352x448 1 License-Plate, 247.9ms
# image 33/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0568.jpg: 288x448 1 License-Plate, 313.1ms
# image 34/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0569.jpg: 352x448 1 License-Plate, 1479.6ms
# image 35/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\IMG_0570.jpg: 352x448 1 License-Plate, 297.1ms
# image 36/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\Image .png: 448x448 1 License-Plate, 312.1ms
# image 37/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_094926329.jpg: 256x448 1 License-Plate, 1105.8ms
# image 38/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_094938026.jpg: 256x448 1 License-Plate, 237.3ms
# image 39/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_094946132.jpg: 256x448 1 License-Plate, 203.4ms
# image 40/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_094951899.jpg: 256x448 2 License-Plates, 344.9ms
# image 41/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_094959264.jpg: 256x448 1 License-Plate, 1567.4ms
# image 42/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095022850.jpg: 256x448 1 License-Plate, 405.9ms
# image 43/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095032661.jpg: 256x448 2 License-Plates, 237.6ms
# image 44/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095042811.jpg: 256x448 1 License-Plate, 245.9ms
# image 45/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095052884.jpg: 256x448 1 License-Plate, 1020.1ms
# image 46/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095103559.jpg: 256x448 1 License-Plate, 236.8ms
# image 47/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095112482.jpg: 256x448 1 License-Plate, 1326.8ms
# image 48/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095129495.jpg: 256x448 1 License-Plate, 201.8ms
# image 49/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095142454.jpg: 256x448 1 License-Plate, 1025.8ms
# image 50/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210921_095212294.jpg: 256x448 1 License-Plate, 269.2ms
# image 51/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210923_071335579.jpg: 256x448 1 License-Plate, 324.3ms
# image 52/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210923_071344764.jpg: 256x448 1 License-Plate, 1109.3ms
# image 53/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\PXL_20210923_071356001.jpg: 256x448 1 License-Plate, 335.3ms
# image 54/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.43.49 (1).jpeg: 288x448 1 License-Plate, 336.9ms
# image 55/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.43.49.jpeg: 256x448 1 License-Plate, 261.0ms
# image 56/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.43.50.jpeg: 288x448 1 License-Plate, 341.2ms
# image 57/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.50.26 (1).jpeg: 448x448 1 License-Plate, 478.0ms
# image 58/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.50.26.jpeg: 448x352 2 License-Plates, 1047.1ms
# image 59/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.58.05.jpeg: 320x448 1 License-Plate, 287.3ms
# image 60/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.58.41.jpeg: 224x448 1 License-Plate, 296.8ms
# image 61/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.59.07.jpeg: 320x448 1 License-Plate, 332.5ms
# image 62/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 12.59.56.jpeg: 256x448 2 License-Plates, 250.8ms
# image 63/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 13.00.02.jpeg: 352x448 1 License-Plate, 330.9ms
# image 64/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 13.00.24.jpeg: 288x448 1 License-Plate, 265.1ms
# image 65/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 13.00.58.jpeg: 192x448 1 License-Plate, 278.2ms
# image 66/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 13.04.51.jpeg: 288x448 1 License-Plate, 577.2ms
# image 67/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.33.58 1.jpeg: 288x448 1 License-Plate, 1174.0ms
# image 68/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.33.59 (2).jpeg: 288x448 1 License-Plate, 636.5ms
# image 69/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.33.59 (3).jpeg: 224x448 1 License-Plate, 283.6ms
# image 70/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.33.59 2.jpeg: 288x448 1 License-Plate, 208.9ms
# image 71/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.33.59.jpeg: 192x448 1 License-Plate, 188.7ms
# image 72/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.00 (1).jpeg: 256x448 2 License-Plates, 198.8ms
# image 73/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.00 (2).jpeg: 256x448 1 License-Plate, 189.2ms
# image 74/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.00.jpeg: 288x448 1 License-Plate, 227.3ms
# image 75/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.01 (1).jpeg: 320x448 1 License-Plate, 304.7ms
# image 76/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.01 3.jpeg: 320x448 1 License-Plate, 210.8ms
# image 77/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.01.jpeg: 288x448 1 License-Plate, 181.7ms
# image 78/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.02 (1).jpeg: 320x448 1 License-Plate, 178.2ms
# image 79/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.02 (2).jpeg: 288x448 1 License-Plate, 170.1ms
# image 80/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.02 (3).jpeg: 224x448 1 License-Plate, 140.1ms
# image 81/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-12 at 14.34.02.jpeg: 288x448 1 License-Plate, 148.3ms
# image 82/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-16 at 13.06.56.jpeg: 352x448 1 License-Plate, 194.0ms
# image 83/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-16 at 13.08.31.jpeg: 352x448 1 License-Plate, 156.4ms
# image 84/84 C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\BD_LicensePlate\images\test\WhatsApp Image 2025-09-16 at 13.09.22.jpeg: 352x448 1 License-Plate, 134.1ms
# Speed: 12.4ms preprocess, 520.2ms inference, 5.4ms postprocess per image at shape (1, 3, 352, 448)
# Results saved to C:\Users\adria\OneDrive - UAB\4 ENGINY\Processament Imatge i Video\Repte Matriculas\License-Plate-Detection\segmentation\runs\detect\predict
# Recorte guardado en Crops\crop_0_IMG_0535.jpg
# Recorte guardado en Crops\crop_0_IMG_0536.jpg
# Recorte guardado en Crops\crop_0_IMG_0538.jpg
# Recorte guardado en Crops\crop_0_IMG_0539.jpg
# Recorte guardado en Crops\crop_1_IMG_0539.jpg
# Recorte guardado en Crops\crop_0_IMG_0540.jpg
# Recorte guardado en Crops\crop_0_IMG_0541.jpg
# Recorte guardado en Crops\crop_1_IMG_0541.jpg
# Recorte guardado en Crops\crop_0_IMG_0542.jpg
# Recorte guardado en Crops\crop_0_IMG_0543.jpg
# Recorte guardado en Crops\crop_0_IMG_0544.jpg
# Recorte guardado en Crops\crop_0_IMG_0545.jpg
# Recorte guardado en Crops\crop_0_IMG_0546.jpg
# Recorte guardado en Crops\crop_0_IMG_0547.jpg
# Recorte guardado en Crops\crop_0_IMG_0548.jpg
# Recorte guardado en Crops\crop_0_IMG_0549.jpg
# Recorte guardado en Crops\crop_0_IMG_0550.jpg
# Recorte guardado en Crops\crop_0_IMG_0551.jpg
# Recorte guardado en Crops\crop_0_IMG_0552.jpg
# Recorte guardado en Crops\crop_0_IMG_0553.jpg
# Recorte guardado en Crops\crop_0_IMG_0554.jpg
# Recorte guardado en Crops\crop_0_IMG_0555.jpg
# Recorte guardado en Crops\crop_0_IMG_0556.jpg
# Recorte guardado en Crops\crop_0_IMG_0557.jpg
# Recorte guardado en Crops\crop_0_IMG_0558.jpg
# Recorte guardado en Crops\crop_0_IMG_0559.jpg
# Recorte guardado en Crops\crop_1_IMG_0559.jpg
# Recorte guardado en Crops\crop_0_IMG_0560.jpg
# Recorte guardado en Crops\crop_0_IMG_0561.jpg
# Recorte guardado en Crops\crop_0_IMG_0562.jpg
# Recorte guardado en Crops\crop_1_IMG_0562.jpg
# Recorte guardado en Crops\crop_0_IMG_0563.jpg
# Recorte guardado en Crops\crop_0_IMG_0564.jpg
# Recorte guardado en Crops\crop_1_IMG_0564.jpg
# Recorte guardado en Crops\crop_0_IMG_0565.jpg
# Recorte guardado en Crops\crop_0_IMG_0566.jpg
# Recorte guardado en Crops\crop_0_IMG_0567.jpg
# Recorte guardado en Crops\crop_0_IMG_0568.jpg
# Recorte guardado en Crops\crop_0_IMG_0569.jpg
# Recorte guardado en Crops\crop_0_IMG_0570.jpg
# Recorte guardado en Crops\crop_0_Image .png
# Recorte guardado en Crops\crop_0_PXL_20210921_094926329.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_094938026.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_094946132.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_094951899.jpg
# Recorte guardado en Crops\crop_1_PXL_20210921_094951899.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_094959264.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095022850.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095032661.jpg
# Recorte guardado en Crops\crop_1_PXL_20210921_095032661.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095042811.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095052884.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095103559.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095112482.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095129495.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095142454.jpg
# Recorte guardado en Crops\crop_0_PXL_20210921_095212294.jpg
# Recorte guardado en Crops\crop_0_PXL_20210923_071335579.jpg
# Recorte guardado en Crops\crop_0_PXL_20210923_071344764.jpg
# Recorte guardado en Crops\crop_0_PXL_20210923_071356001.jpg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.43.49 (1).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.43.49.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.43.50.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.50.26 (1).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.50.26.jpeg
# Recorte guardado en Crops\crop_1_WhatsApp Image 2025-09-12 at 12.50.26.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.58.05.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.58.41.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.59.07.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 12.59.56.jpeg
# Recorte guardado en Crops\crop_1_WhatsApp Image 2025-09-12 at 12.59.56.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 13.00.02.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 13.00.24.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 13.00.58.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 13.04.51.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.33.58 1.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.33.59 (2).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.33.59 (3).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.33.59 2.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.33.59.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.00 (1).jpeg
# Recorte guardado en Crops\crop_1_WhatsApp Image 2025-09-12 at 14.34.00 (1).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.00 (2).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.00.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.01 (1).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.01 3.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.01.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.02 (1).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.02 (2).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.02 (3).jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-12 at 14.34.02.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-16 at 13.06.56.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-16 at 13.08.31.jpeg
# Recorte guardado en Crops\crop_0_WhatsApp Image 2025-09-16 at 13.09.22.jpeg
